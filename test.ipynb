# %%
import pyttsx3

# %%
engine = pyttsx3.init("sapi5")
engine.setProperty("rate", 170)
voices = engine.getProperty("voices")
engine.setProperty("voice", voices[0].id)

# %%
print(voices)
# Out:
# [<pyttsx3.voice.Voice object at 0x0000022962656790>, <pyttsx3.voice.Voice object at 0x0000022962654890>]
